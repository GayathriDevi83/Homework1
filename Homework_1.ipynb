# %% [markdown]
# # Getting familiar with Data types and Visualization

# %% [markdown]
# 1.   Step 1: Download the dataset files belong to the following data formats from internet. The files may belong to any dataset available online.
# 2.   Step 2: Read these files inside the python code. Some of the file formats cannot be read using default python packages. In this case, explore the python packages suitable for reading the files.
# 3.   Step 3: Print the properties of the data files such as size, shape, dimensions, etc.
# 4.   Step 4: Visualize each of these data files using graphs, diagrams, etc.
#
#
# *    Table data visualization: line graph, bar graph, histogram chart, pie chart, scatter plot
# *    Image visualization: image plot, 3d plot
# *    Video visualization: video player
# *    Audio visualization: audio player, spectrogram
# *    Text visualization: Word cloud, bubble cloud (some more in http://vallandingham.me/textvis-talk/)

# %% [markdown]
# # Type 1
#
# ### Tabular, Spreadsheet and Interchange Data Formats
#
# *   "Table" — generic tabular data (.dat), "CSV" — comma-separated values (.csv), "TSV" — tab-separated values (.tsv), “ARFF” - Attribute-Relation File Format (.arff) – Read and visualize the data
# *   "XLS" — Excel spreadsheet (.xls), "XLSX" — Excel 2007 format (.xlsx), "ODS" — OpenDocument spreadsheet (.ods), "SXC" — OpenOffice 1.0 spreadsheet file (.sxc), "DIF" — VisiCalc data interchange format (.dif) – Read and visualize the data
# *   "JSON" — JavaScript Object Notation (.json), "UBJSON" — Universal Binary JSON (.ubj), “HTML” – Hypertext Markup Language (.html), “XML” - eXtensible Markup Language (.xml)  - Read and Parse the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Add your code here
import pandas as pd
x=pd.read_csv('/content/drive/My Drive/salary1.csv')
x
# Out:
#     years  salary
# 0       1   20000
# 1       2   30000
# 2       3   40000
# 3       4   50000
# 4       5   60000
# 5       6   70000
# 6       7   80000
# 7       8   90000
# 8       9  100000
# 9      10  110000
# 10     11  120000
# 11     12  130000
# 12     13  140000
# 13     14  150000
# 14     15  160000
# 15     16  170000
# 16     17  180000
# 17     18  190000
# 18     19  200000
# 19     20  210000

# %%
# Add your code here
import matplotlib.pyplot as plt
plt.bar(x = x['years'], height = x['salary'])
plt.xlabel('years')
plt.ylabel('salary')
plt.title('Salary Structure')
# Out:
# Text(0.5, 1.0, 'Salary Structure')

# %% [markdown]
# # Type 2
#
# ### Data File Formats
#
# *   PKL – Pickle format, HDF5, Zip, SQL, MAT, NPY, NPZ – Read and display the data

# %%
# Add your code here
# npz
from tensorflow import keras

(train_images,train_labels),(test_images,test_labels)=keras.datasets.mnist.load_data()

# %%
idx=30
plt.imshow(train_images[idx])
print(train_labels[idx])
# Out:
# 3

# %% [markdown]
# # Type 3
#
# ### Image Data Formats
# *   JPG, PNG, BMP, TIFF – Read and display the image
# *   3D medical Images: DICOM, MHA – Read and display the image

# %%
# Add your code here
y = plt.imread('/content/drive/My Drive/day11/FDP/img_007_SRF_2_HR.png')
plt.imshow(y)

# %%
# Add your code here

# %% [markdown]
# # Type 4
#
# ### Video Data Formats
# *   MP4, AVI, MPEG – Read and play the video

# %%
# Add your code here

# %% [markdown]
# # Type 5
#
# ### Audio Data Formats
# *   MP3, MIDI, WAV – Read and play the audio

# %%
import numpy as np
from glob import glob
import librosa as lr

# %%
# Add your code here
file = '/content/drive/My Drive/file_example_WAV_1MG.WAV'
audio_file = glob(file + '/*.wav')

# %%
# Add your code here

# %% [markdown]
# # Type 6
#
# ### Text Data Formats
#
# *   TXT, PDF, DOC – Read and parse the data

# %%
pip install docx2txt
# Out:
# Collecting docx2txt
#   Downloading https://files.pythonhosted.org/packages/7d/7d/60ee3f2b16d9bfdfa72e8599470a2c1a5b759cb113c6fe1006be28359327/docx2txt-0.8.tar.gz
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-cp37-none-any.whl size=3963 sha256=d3fb277148642093f685c4e885ed959deda2afb6b479db4f8036122f7ffbdea8
#   Stored in directory: /root/.cache/pip/wheels/b2/1f/26/a051209bbb77fc6bcfae2bb7e01fa0ff941b82292ab084d596
# Successfully built docx2txt
# Installing collected packages: docx2txt
# Successfully installed docx2txt-0.8

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-56c4490a-742f-4f77-b603-aefe6f3a64e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56c4490a-742f-4f77-b603-aefe6f3a64e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving display.docx to display.docx
# {'display.docx': b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\xdd\xfc\x957f\x01\x00\x00 \x05\x00\x00\x13\x00\x08\x02[Content_Types].xml \xa2\x04\x02(T\xcbn\xc20\x10\xbcW\xea?D\xbeV\x89\xa1\x87\xaa\xaa\x08\x1c\xfa8\xb6H\xa5\x1f`\xec\rX\xf5K\xf6\xf2\xfa\xfbn\x02DU\x0bA*\xe5\x12)Y\xef\xcc\xec\xec\xc4\x83\xd1\xda\x9al\t1i\xefJ\xd6/z,\x03\'\xbd\xd2nV\xb2\x8f\xc9K~\xcf\xb2\x84\xc2)a\xbc\x83\x92m \xb1\xd1\xf0\xfaj0\xd9\x04H\x19u\xbbT\xb29bx\xe0<\xc99X\x91\n\x1f\xc0Q\xa5\xf2\xd1\n\xa4\xd78\xe3A\xc8O1\x03~\xdb\xeb\xddq\xe9\x1d\x82\xc3\x1ck\x0c6\x1c<A%\x16\x06\xb3\xe75}\xde*\x89`\x12\xcb\x1e\xb7\x07k\xae\x92\x89\x10\x8c\x96\x02I)_:\xf5\x83%\xdf1\x14\xd4\xd9\x9cIs\x1d\xd2\r\xc9`\xfc C]9N\xb0\xeb{#k\xa2V\x90\x8dE\xc4WaI\x06_\xf9\xa8\xb8\xf2rai\x86\xa2\x1b\xe6\x80N_UZB\xdb_\xa3\x85\xe8%\xa4D\x9e[S\xb4\x15+\xb4\xdb\xeb?\xaa#\xe1\xc6@\xfa\x7f\x15[\xdc.z\xd29\x8e>$N{9\x9b\x1f\xea\xcd+P9Y\x11 \xa2\x86vu\xc7G\x07D\xb2\xec\x12\xc3\xef\x90\xbb\xc6oR\x80\x94w\xe0\xcd\xb3\x7f\xb6\x07\r\xccI\xca\x8a~\x89\x89\x98\x1a8\x9b\xefW\xf2Z\xe8\x93"V0}\xbf\x98\xfb\xdf\xc0\xbb\x84\xb4\xf9\x93>\xfe\xc1\x8c\xfduQw\x1fH\x1do\xee\xb7\xe1\x17\x00\x00\x00\xff\xff\x03\x00PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\x1e\x91\x1a\xb7\xf3\x00\x00\x00N\x02\x00\x00\x0b\x00\x08\x02_rels/.rels \xa2\x04\x02(\ ...

# %%
# Add your code here
import docx2txt
readfile = docx2txt.process("display.docx")
print(readfile)
# Out:
# HI….WELCOME
